# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
a = [1,2,3]
plt.plot(a)

# %%
plt.show()  # x axis is index[0,1,2]

# %%
a = [1,2,3]
b = [4,5,6]
plt.plot(a,b)

# %%
plt.show() # x axix is a, y axis is b,  size of a and b must be same.

# %%
a = [1,2,3]
b = [4,5,6]
plt.plot(a,b)
# %matplotlib inline  # magic function start with %

# %%
plt.plot(a,b)

# %%
plt.plot(a,b)

# %%
# %timeit np.arange(10)
# Out:
# The slowest run took 26.21 times longer than the fastest. This could mean that an intermediate result is being cached.
# 1000000 loops, best of 3: 560 ns per loop

# %%
plt.plot(a,b,'--')

# %%
plt.plot(a,b,'*')

# %%
plt.plot(a,b,'r--')

# %%
c = [10,8,6]
d = [1,8,3]
plt.plot(a,b,'r--',c,d,'b*')

# %%
t = np.arange(0.0,2.0,0.1)
t.size
# Out:
# 20

# %%
s = np.sin(t*np.pi)

# %%
s
# Out:
# array([  0.00000000e+00,   3.09016994e-01,   5.87785252e-01,
#          8.09016994e-01,   9.51056516e-01,   1.00000000e+00,
#          9.51056516e-01,   8.09016994e-01,   5.87785252e-01,
#          3.09016994e-01,   1.22464680e-16,  -3.09016994e-01,
#         -5.87785252e-01,  -8.09016994e-01,  -9.51056516e-01,
#         -1.00000000e+00,  -9.51056516e-01,  -8.09016994e-01,
#         -5.87785252e-01,  -3.09016994e-01])

# %%
s.size
# Out:
# 20

# %%
plt.plot(t,s,'r--', t*2,s,'--')

# %%
plt.plot(t,s,'r--', label = 'aaaa')
plt.plot(t*2,s,'--',label = 'bbbb')
plt.xlabel('this is x')
plt.ylabel('this is y')
plt.title('this is a demo')
plt.legend()
