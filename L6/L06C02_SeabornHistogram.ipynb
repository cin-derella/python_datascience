# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import seaborn as sns

# %%
s1 = Series(np.random.randn(1000))
plt.hist(s1)
# Out:
# (array([   3.,   10.,   46.,  119.,  233.,  266.,  198.,   91.,   29.,    5.]),
#  array([-3.61796281, -2.93764121, -2.25731961, -1.57699801, -0.89667642,
#         -0.21635482,  0.46396678,  1.14428838,  1.82460997,  2.50493157,
#          3.18525317]),
#  <a list of 10 Patch objects>)

# %%
s1.plot(kind= 'kde')

# %%
sns.distplot(s1,hist = False, kde = True, rug = True)

# %%
sns.kdeplot(s1,shade = True,color = 'r')

# %%
sns.plt.hist(s1)
# Out:
# (array([   3.,   10.,   46.,  119.,  233.,  266.,  198.,   91.,   29.,    5.]),
#  array([-3.61796281, -2.93764121, -2.25731961, -1.57699801, -0.89667642,
#         -0.21635482,  0.46396678,  1.14428838,  1.82460997,  2.50493157,
#          3.18525317]),
#  <a list of 10 Patch objects>)

# %%
sns.rugplot(s1,height = 0.2, axis = 'x')
