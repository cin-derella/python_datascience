# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
from datetime import datetime

# %%
t1 = datetime(2020,4,1)

# %%
t1
# Out:
# datetime.datetime(2020, 4, 1, 0, 0)

# %%
data_list = [
    datetime(2013,5,7),
    datetime(2015,6,7),
    datetime(2017,9,25),
    datetime(2018,3,21),
    datetime(2019,10,5),
    datetime(2019,8,7)
]

# %%
s1 = Series(np.random.rand(6),index = data_list)

# %%
s1
# Out:
# 2013-05-07    0.750841
# 2015-06-07    0.638744
# 2017-09-25    0.000582
# 2018-03-21    0.619190
# 2019-10-05    0.439913
# 2019-08-07    0.653596
# dtype: float64

# %%
s1.values
# Out:
# array([ 0.88477886,  0.15920637,  0.05036597,  0.61719295,  0.35330053])

# %%
s1.index
# Out:
# DatetimeIndex(['2013-05-07', '2015-06-07', '2017-09-25', '2018-03-21',
#                '2019-10-05'],
#               dtype='datetime64[ns]', freq=None)

# %%
s1[1]
# Out:
# 0.1592063678221417

# %%
s1[datetime(2015,6,7)]
# Out:
# 0.1592063678221417

# %%
s1['2015-6-7']
# Out:
# 0.1592063678221417

# %%
s1['20150607']
# Out:
# 0.1592063678221417

# %%
s1['2019']
# Out:
# 2019-10-05    0.439913
# 2019-08-07    0.653596
# dtype: float64

# %%
s1['2019-10']
# Out:
# 2019-10-05    0.439913
# dtype: float64

# %%
date_list_new = pd.date_range('2019-01',periods =100,freq='W')

# %%
date_list_new
# Out:
# DatetimeIndex(['2019-01-06', '2019-01-13', '2019-01-20', '2019-01-27',
#                '2019-02-03', '2019-02-10', '2019-02-17', '2019-02-24',
#                '2019-03-03', '2019-03-10', '2019-03-17', '2019-03-24',
#                '2019-03-31', '2019-04-07', '2019-04-14', '2019-04-21',
#                '2019-04-28', '2019-05-05', '2019-05-12', '2019-05-19',
#                '2019-05-26', '2019-06-02', '2019-06-09', '2019-06-16',
#                '2019-06-23', '2019-06-30', '2019-07-07', '2019-07-14',
#                '2019-07-21', '2019-07-28', '2019-08-04', '2019-08-11',
#                '2019-08-18', '2019-08-25', '2019-09-01', '2019-09-08',
#                '2019-09-15', '2019-09-22', '2019-09-29', '2019-10-06',
#                '2019-10-13', '2019-10-20', '2019-10-27', '2019-11-03',
#                '2019-11-10', '2019-11-17', '2019-11-24', '2019-12-01',
#                '2019-12-08', '2019-12-15', '2019-12-22', '2019-12-29',
# ...

# %%
date_list_new = pd.date_range('2019-01-01',periods =100,freq='5H')

# %%
date_list_new
# Out:
# DatetimeIndex(['2019-01-01 00:00:00', '2019-01-01 05:00:00',
#                '2019-01-01 10:00:00', '2019-01-01 15:00:00',
#                '2019-01-01 20:00:00', '2019-01-02 01:00:00',
#                '2019-01-02 06:00:00', '2019-01-02 11:00:00',
#                '2019-01-02 16:00:00', '2019-01-02 21:00:00',
#                '2019-01-03 02:00:00', '2019-01-03 07:00:00',
#                '2019-01-03 12:00:00', '2019-01-03 17:00:00',
#                '2019-01-03 22:00:00', '2019-01-04 03:00:00',
#                '2019-01-04 08:00:00', '2019-01-04 13:00:00',
#                '2019-01-04 18:00:00', '2019-01-04 23:00:00',
#                '2019-01-05 04:00:00', '2019-01-05 09:00:00',
#                '2019-01-05 14:00:00', '2019-01-05 19:00:00',
#                '2019-01-06 00:00:00', '2019-01-06 05:00:00',
#                '2019-01-06 10:00:00', '2019-01-06 15:00:00',
#                '2019-01-06 20:00:00', '2019-01-07 01:00:00',
# ...

# %%
s2 = Series(np.random.rand(100),index = date_list_new)

# %%
s2
# Out:
# 2019-01-01 00:00:00    0.958781
# 2019-01-01 05:00:00    0.514639
# 2019-01-01 10:00:00    0.756588
# 2019-01-01 15:00:00    0.327918
# 2019-01-01 20:00:00    0.136582
# 2019-01-02 01:00:00    0.022072
# 2019-01-02 06:00:00    0.444914
# 2019-01-02 11:00:00    0.818275
# 2019-01-02 16:00:00    0.527498
# 2019-01-02 21:00:00    0.812603
# 2019-01-03 02:00:00    0.013573
# 2019-01-03 07:00:00    0.947716
# 2019-01-03 12:00:00    0.141334
# 2019-01-03 17:00:00    0.046740
# 2019-01-03 22:00:00    0.269806
# 2019-01-04 03:00:00    0.609827
# 2019-01-04 08:00:00    0.233189
# 2019-01-04 13:00:00    0.195957
# 2019-01-04 18:00:00    0.958506
# 2019-01-04 23:00:00    0.721259
# 2019-01-05 04:00:00    0.366566
# 2019-01-05 09:00:00    0.312582
# 2019-01-05 14:00:00    0.814921
# 2019-01-05 19:00:00    0.287587
# 2019-01-06 00:00:00    0.729275
# 2019-01-06 05:00:00    0.294162
# 2019-01-06 10:00:00    0.777537
# 2019-01-06 15:00:00    0.232573
# 2019-01-06 20:00:00    0.480485
# ...
