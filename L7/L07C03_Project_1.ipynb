# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

import pandas_datareader as pdr

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

from datetime import datetime

# %%
a = 1
b = 2
a+b
# Out:
# 3

# %%
start = datetime(2017,11,7)
sogou= pdr.get_data_yahoo('SOGO',start = start)

# %%
sogou.head()
# Out:
#              Open   High    Low  Close  Adj Close    Volume
# Date
# 2017-11-09  13.00  14.70  13.00  13.50      13.50  42527100
# 2017-11-10  14.04  14.69  13.68  13.85      13.85  12580400
# 2017-11-13  14.00  14.07  13.66  13.82      13.82   4344900
# 2017-11-14  13.70  13.84  13.00  13.00      13.00   8635100
# 2017-11-15  12.88  13.00  12.50  12.69      12.69   6820800

# %%
sogou.shape
# Out:
# (66, 6)

# %%
start = datetime(2017,11,7)
bilibili= pdr.get_data_yahoo('BILI',start = start)

# %%
bilibili.head()
# Out:
#              Open   High     Low  Close  Adj Close    Volume
# Date
# 2018-03-28   9.80  11.26   9.620  11.24      11.24  23929600
# 2018-03-29  11.50  11.80  10.650  11.00      11.00   5863900
# 2018-04-02  11.05  11.50  10.910  11.00      11.00   2771000
# 2018-04-03  11.50  11.50  10.791  10.91      10.91   2509600
# 2018-04-04  10.75  11.08  10.550  10.97      10.97   1498200

# %%
bilibili.shape
# Out:
# (66, 6)

# %%
sogou['Adj Close'].plot(legend = True)

# %%
sogou['Volume'].plot(legend = True)

# %%
sogou['Adj Close'].plot()
bilibili['Adj Close'].plot()

# %%
sogou['H-L'] = sogou['High']-sogou['Low']

# %%
sogou.head()
# Out:
#              Open   High    Low  Close  Adj Close    Volume   H-L
# Date
# 2017-11-09  13.00  14.70  13.00  13.50      13.50  42527100  1.70
# 2017-11-10  14.04  14.69  13.68  13.85      13.85  12580400  1.01
# 2017-11-13  14.00  14.07  13.66  13.82      13.82   4344900  0.41
# 2017-11-14  13.70  13.84  13.00  13.00      13.00   8635100  0.84
# 2017-11-15  12.88  13.00  12.50  12.69      12.69   6820800  0.50

# %%
sogou['H-L'].plot()

# %%
sogou['Daily Return']=sogou['Adj Close'].pct_change()

# %%
sogou['Daily Return'].plot(figsize=(10,4), linestyle = '--', marker = 'o')

# %%
sogou['Daily Return'].plot(kind='hist',rwidth = 0.8)

# %%
sns.distplot(sogou['Daily Return'].dropna(),bins =20, color = 'orange')
