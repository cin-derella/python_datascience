# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

import pandas_datareader as pdr

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

from datetime import datetime
# Out:
# /Users/dante/opt/anaconda3/lib/python3.7/site-packages/pandas_datareader/compat/__init__.py:7: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   from pandas.util.testing import assert_frame_equal

# %%
start = datetime(2020,1,1)
end = datetime(2020,4,1)
company = ['SOGO']
tech_df = pdr.get_data_yahoo(company, start = start, end=end)['Adj Close']

# %%
tech_df.head().index
# Out:
# DatetimeIndex(['2017-11-09', '2017-11-10', '2017-11-13', '2017-11-14',
#                '2017-11-15'],
#               dtype='datetime64[ns]', name='Date', freq=None)

# %%
tech_df = tech_df.pct_change()

# %%
tech_df
# Out:
# Symbols         SOGO
# Date
# 2019-12-31       NaN
# 2020-01-02  0.039560
# 2020-01-03 -0.002114
# 2020-01-06  0.000000
# 2020-01-07  0.010593
# 2020-01-08  0.006289
# 2020-01-09  0.029167
# 2020-01-10 -0.008097
# 2020-01-13  0.079592
# 2020-01-14  0.026465
# 2020-01-15 -0.016575
# 2020-01-16  0.000000
# 2020-01-17  0.016854
# 2020-01-21 -0.009208
# 2020-01-22 -0.018587
# 2020-01-23 -0.017045
# 2020-01-24 -0.052023
# 2020-01-27 -0.052846
# 2020-01-28 -0.008584
# 2020-01-29 -0.043290
# 2020-01-30 -0.040724
# 2020-01-31 -0.037736
# 2020-02-03  0.051471
# 2020-02-04  0.018648
# 2020-02-05 -0.006865
# 2020-02-06 -0.006912
# 2020-02-07 -0.004640
# 2020-02-10  0.006993
# 2020-02-11  0.032407
# 2020-02-12  0.008969
# ...              ...
# 2020-02-24 -0.007299
# 2020-02-25 -0.041667
# 2020-02-26  0.035806
# 2020-02-27 -0.019753
# 2020-02-28  0.070529
# 2020-03-02 -0.044706
# 2020-03-03 -0.004926
# 2020-03-04  0.002475
# 2020-03-05 -0.027161
# 2020-03-06 -0.022843
# 2020-03-09  0.007792
# ...

# %%
tech_df.plot()

# %%
tech_df[['SOGO','BILI']].plot()

# %%
tech_dr.head()['SOGO']
# Out:
# Date
# 2017-11-09         NaN
# 2017-11-10    0.025926
# 2017-11-13   -0.002166
# 2017-11-14   -0.059334
# 2017-11-15   -0.023846
# Name: SOGO, dtype: float64

# %%
longdr = tech_dr.head()['SOGO']

# %%
mydf = DataFrame(['SOGO']*5, index = [0,1,2,3,4], columns = ['Name'])
mydf
# Out:
#    Name
# 0  SOGO
# 1  SOGO
# 2  SOGO
# 3  SOGO
# 4  SOGO

# %%
mydf['Name'][0] = 'BILI'
mydf
# Out:
#    Name
# 0  BILI
# 1  SOGO
# 2  SOGO
# 3  SOGO
# 4  SOGO

# %%
mydf['a'] = tech_df['SOGO']

# %%
tech_df
del tech_df['BILI']

# %%
tech_df
# Out:
# Symbols           DAO       HUYA         IQ  SOGO
# Date
# 2019-12-31  14.080000  17.950001  21.110001  4.55
# 2020-01-02  15.000000  20.020000  22.969999  4.73
# 2020-01-03  14.350000  19.240000  23.040001  4.72
# 2020-01-06  14.920000  19.830000  23.120001  4.72
# 2020-01-07  15.930000  20.820000  23.360001  4.77
# 2020-01-08  15.720000  20.950001  24.020000  4.80
# 2020-01-09  15.880000  20.980000  24.520000  4.94
# 2020-01-10  15.850000  20.389999  23.900000  4.90
# 2020-01-13  16.500000  21.040001  23.980000  5.29
# 2020-01-14  16.000000  20.590000  23.870001  5.43
# 2020-01-15  15.870000  20.680000  23.680000  5.34
# 2020-01-16  16.150000  20.500000  23.780001  5.34
# 2020-01-17  16.100000  20.430000  23.910000  5.43
# 2020-01-21  16.000000  20.480000  23.910000  5.38
# 2020-01-22  16.059999  18.389999  24.160000  5.28
# 2020-01-23  15.680000  19.000000  23.930000  5.19
# 2020-01-24  16.100000  18.150000  21.889999  4.92
# 2020-01-27  16.139999  17.930000  21.990000  4.66
# ...

# %%
company = ['SOGO']
tech_df_sogo = pdr.get_data_yahoo(company, start = start, end=end)['Adj Close'].pct_change()
company = ['BILI']
tech_df_bili = pdr.get_data_yahoo(company, start = start,end=end)['Adj Close'].pct_change()
company = ['DAO']
tech_df_dao = pdr.get_data_yahoo(company, start = start,end=end)['Adj Close'].pct_change()

# %%
tech_df_sogo['Name'] = ['SOGO']*len(tech_df_sogo)
tech_df_bili['Name'] = ['BILI']*len(tech_df_bili)
tech_df_dao['Name'] = ['DAO']*len(tech_df_dao)

# %%
tech_df_sogo = tech_df_sogo.rename(columns = {'SOGO':'Pct'})
tech_df_bili = tech_df_bili.rename(columns = {'BILI':'Pct'})
tech_df_dao = tech_df_dao.rename(columns = {'DAO':'Pct'})

# %%
tech_dd = pd.concat([tech_df_sogo, tech_df_bili, tech_df_dao], sort=False)

# %%
tech_dd['DateValue'] = tech_dd.index

# %%
def getdays(thedate):
    s = thedate - datetime(2019,12,31);
    return s.days
    #return str(s).replace(' days', '')

# %%
tech_dd['DateValue'] = tech_dd['DateValue'].map(getdays)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-575f28d98e1c> in <module>
# ----> 1 tech_dd['days from 2020.01.01'] = tech_dd['DateValue'].map(getdays)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in map(self, arg, na_action)
#    3628         dtype: object
#    3629         """
# -> 3630         new_values = super()._map_values(arg, na_action=na_action)
#    3631         return self._constructor(new_values, index=self.index).__finalize__(self)
#    3632
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/base.py in _map_values(self, mapper, na_action)
#    1152
#    1153         # mapper is a function
# -> 1154         new_values = map_f(values, mapper)
#    1155
#    1156         return new_values
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-26-bc423258b424> in getdays(thedate)
# ...

# %%
tech_dd['days from 2020.01.01'] = tech_dd['DateValue']

# %%
tech_dd = tech_dd.dropna()

# %%
tech_dd
# Out:
# Symbols          Pct  Name  DateValue
# Date
# 2020-01-02  0.039560  SOGO          2
# 2020-01-03 -0.002114  SOGO          3
# 2020-01-06  0.000000  SOGO          6
# 2020-01-07  0.010593  SOGO          7
# 2020-01-08  0.006289  SOGO          8
# ...              ...   ...        ...
# 2020-03-26 -0.001566   DAO         86
# 2020-03-27 -0.040251   DAO         87
# 2020-03-30  0.003813   DAO         90
# 2020-03-31  0.141617   DAO         91
# 2020-04-01 -0.016160   DAO         92
#
# [189 rows x 3 columns]

# %%
sns.lmplot('days from 2020.01.01', 'Pct',tech_dd,hue='Name', fit_reg = False)

# %%
sns.pairplot(tech_dr.dropna())

# %%
tech_dr['SOGO'].quantile(0.6)
# Out:
# 0.0024716416388770313

# %%
tech_dr['BILI'].quantile(0.2)
# Out:
# -0.027228555721383559
