# %%
import numpy as np
import pandas as pd
import tushare as ts

# %%
import tushare as ts

df = ts.get_tick_data('600848',date='2018-12-12',src='tt')
df.head(10)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>time</th>
#       <th>price</th>
#       <th>change</th>
#       <th>volume</th>
#       <th>amount</th>
#       <th>type</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>09:30:03</td>
#       <td>20.68</td>
#       <td>0.03</td>
#       <td>24</td>
#       <td>49616</td>
#       <td>买盘</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>09:30:05</td>
#       <td>20.70</td>
#       <td>0.02</td>
#       <td>1</td>
#       <td>2070</td>
#       <td>卖盘</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>09:30:15</td>
#       <td>20.77</td>
#       <td>0.07</td>
# ...

# %%
df1 = df[['time','price']]
df1
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>time</th>
#       <th>price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>09:30:03</td>
#       <td>20.68</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>09:30:05</td>
#       <td>20.70</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>09:30:15</td>
#       <td>20.77</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>09:30:26</td>
#       <td>20.78</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>09:30:33</td>
#       <td>20.78</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#     </tr>
# ...

# %%
df2 = df[['time','type']]
df2
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>time</th>
#       <th>type</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>09:30:03</td>
#       <td>买盘</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>09:30:05</td>
#       <td>卖盘</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>09:30:15</td>
#       <td>买盘</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>09:30:26</td>
#       <td>买盘</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>09:30:33</td>
#       <td>卖盘</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
# ...

# %%
pd.merge(df1,df2)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>time</th>
#       <th>price</th>
#       <th>type</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>09:30:03</td>
#       <td>20.68</td>
#       <td>买盘</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>09:30:05</td>
#       <td>20.70</td>
#       <td>卖盘</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>09:30:15</td>
#       <td>20.77</td>
#       <td>买盘</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>09:30:26</td>
#       <td>20.78</td>
#       <td>买盘</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>09:30:33</td>
#       <td>20.78</td>
# ...

# %%
#import tushare as ts

df600848 = ts.get_tick_data('600848',date='2019-12-12',src='tt')
df600848.head(10)

df600898 = ts.get_tick_data('600898',date='2019-12-12',src='tt')
df600898.head(10)

display(df600848.head(10),df600898.head(10))
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>time</th>
#       <th>price</th>
#       <th>change</th>
#       <th>volume</th>
#       <th>amount</th>
#       <th>type</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>09:25:04</td>
#       <td>24.12</td>
#       <td>-0.01</td>
#       <td>116</td>
#       <td>279792</td>
#       <td>卖盘</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>09:30:02</td>
#       <td>24.12</td>
#       <td>0.00</td>
#       <td>94</td>
#       <td>226893</td>
#       <td>买盘</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>09:30:05</td>
#       <td>24.12</td>
# ...
