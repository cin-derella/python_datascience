# %%
import numpy as np
import pandas as pd

# %%
csvPath = r'../YCdata/state-abbrevs.csv'
baidu = pd.read_csv(csvPath)  # 要看jupyter在哪个目录打开，以此目录为相对路径
baidu.head(5)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>state</th>
#       <th>abbreviation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Alabama</td>
#       <td>AL</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Alaska</td>
#       <td>AK</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Arizona</td>
#       <td>AZ</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Arkansas</td>
#       <td>AR</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>California</td>
#       <td>CA</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
csvPath = r'../YCdata/baidu.csv'
baidu = pd.read_csv(csvPath)  # 要看jupyter在哪个目录打开，以此目录为相对路径
baidu.head(5)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Name</th>
#       <th>Office Ext.</th>
#       <th>Mobile</th>
#       <th>Name.1</th>
#       <th>Office Ext. .1</th>
#       <th>Mobile .1</th>
#       <th>Name.2</th>
#       <th>Office Ext. .2</th>
#       <th>Mobile .2</th>
#       <th>Name.3</th>
#       <th>...</th>
#       <th>Unnamed: 232</th>
#       <th>Unnamed: 233</th>
#       <th>Unnamed: 234</th>
#       <th>Unnamed: 235</th>
#       <th>Unnamed: 236</th>
#       <th>Unnamed: 237</th>
#       <th>Unnamed: 238</th>
#       <th>Unnamed: 239</th>
#       <th>Unnamed: 240</th>
#       <th>Unnamed: 241</th>
#     </tr>
#   </thead>
#   <tbody>
# ...

# %%
type(baidu)
# Out:
# pandas.core.frame.DataFrame
