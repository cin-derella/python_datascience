# %%
import numpy as np
import pandas as pd
import tushare as ts

# %%
df1 = pd.DataFrame({'name':['huangjian','huangzehe','huangtaoqi'],
                    'age':[30,32,33]})
df2 = pd.DataFrame({'name':['huangtaoqi','huangzehe','huangjian'],
                    'tall':[170,158,180]})
display(df1,df2,pd.merge(df1,df2)) #仅归并匹配的
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>name</th>
#       <th>age</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>huangjian</td>
#       <td>30</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>huangzehe</td>
#       <td>32</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>huangtaoqi</td>
#       <td>33</td>
#     </tr>
#   </tbody>
# </table>
# </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# ...

# %%
df3 = pd.DataFrame({'name':['huangjian','huangzehe','huangtaoqid'],
                    'type':['beijing','shanghai','shanghai']})
df3
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>name</th>
#       <th>type</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>huangjian</td>
#       <td>beijing</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>huangzehe</td>
#       <td>shanghai</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>huangtaoqid</td>
#       <td>shanghai</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df4= pd.DataFrame({'numbers':['10000','5000','200'],
                    'type':['beijing','shanghai','tianjin']})
df4
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>numbers</th>
#       <th>type</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>10000</td>
#       <td>beijing</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>5000</td>
#       <td>shanghai</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>200</td>
#       <td>tianjin</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
pd.merge(df3,df4) # 一对多
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>name</th>
#       <th>type</th>
#       <th>numbers</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>huangjian</td>
#       <td>beijing</td>
#       <td>10000</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>huangzehe</td>
#       <td>shanghai</td>
#       <td>5000</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>huangtaoqid</td>
#       <td>shanghai</td>
#       <td>5000</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df5= pd.DataFrame({'area':['north','south','north'],
                    'type':['beijing','shanghai','shanghai']})
df5
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>area</th>
#       <th>type</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>north</td>
#       <td>beijing</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>south</td>
#       <td>shanghai</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>north</td>
#       <td>shanghai</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
display(df5,pd.merge(df3,df4),pd.merge(df5,pd.merge(df3,df4)))
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>area</th>
#       <th>type</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>north</td>
#       <td>beijing</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>south</td>
#       <td>shanghai</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>north</td>
#       <td>shanghai</td>
#     </tr>
#   </tbody>
# </table>
# </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
# ...
