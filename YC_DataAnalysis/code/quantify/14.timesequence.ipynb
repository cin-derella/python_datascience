# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib
matplotlib.rcParams['font.sans-serif'] = ['SimHei']
matplotlib.rcParams['font.family'] = 'sans-serif'
matplotlib.rcParams['axes.unicode_minus'] = False

# %%
path = '../YCdata/TRD_Index.txt'
Index = pd.read_table(path,sep='\t',index_col='Trddt')
Index
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Indexcd</th>
#       <th>Daywk</th>
#       <th>Opnindex</th>
#       <th>Hiindex</th>
#       <th>Loindex</th>
#       <th>Clsindex</th>
#       <th>Retindex</th>
#     </tr>
#     <tr>
#       <th>Trddt</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2014/1/2</th>
#       <td>1</td>
#       <td>4</td>
#       <td>2112.126</td>
#       <td>2113.110</td>
#       <td>2101.016</td>
#       <td>2109.387</td>
#       <td>-0.003115</td>
#     </tr>
#     <tr>
# ...

# %%
SHindex = Index[Index.Indexcd==1]
SHindex
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Indexcd</th>
#       <th>Daywk</th>
#       <th>Opnindex</th>
#       <th>Hiindex</th>
#       <th>Loindex</th>
#       <th>Clsindex</th>
#       <th>Retindex</th>
#     </tr>
#     <tr>
#       <th>Trddt</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2014/1/2</th>
#       <td>1</td>
#       <td>4</td>
#       <td>2112.126</td>
#       <td>2113.110</td>
#       <td>2101.016</td>
#       <td>2109.387</td>
#       <td>-0.003115</td>
#     </tr>
#     <tr>
# ...

# %%
Clsindex = SHindex.Clsindex
Clsindex
# Out:
# Trddt
# 2014/1/2     2109.387
# 2014/1/3     2083.136
# 2014/1/6     2045.709
# 2014/1/7     2047.317
# 2014/1/8     2044.340
#                ...
# 2015/4/8     3994.811
# 2015/4/9     3957.534
# 2015/4/10    4034.310
# 2015/4/13    4121.715
# 2015/4/14    4135.565
# Name: Clsindex, Length: 311, dtype: float64

# %%
Clsindex.index
# Out:
# Index(['2014/1/2', '2014/1/3', '2014/1/6', '2014/1/7', '2014/1/8', '2014/1/9',
#        '2014/1/10', '2014/1/13', '2014/1/14', '2014/1/15',
#        ...
#        '2015/3/31', '2015/4/1', '2015/4/2', '2015/4/3', '2015/4/7', '2015/4/8',
#        '2015/4/9', '2015/4/10', '2015/4/13', '2015/4/14'],
#       dtype='object', name='Trddt', length=311)

# %%
Clsindex.index = pd.to_datetime(Clsindex.index)
Clsindex
# Out:
# Trddt
# 2014-01-02    2109.387
# 2014-01-03    2083.136
# 2014-01-06    2045.709
# 2014-01-07    2047.317
# 2014-01-08    2044.340
#                 ...
# 2015-04-08    3994.811
# 2015-04-09    3957.534
# 2015-04-10    4034.310
# 2015-04-13    4121.715
# 2015-04-14    4135.565
# Name: Clsindex, Length: 311, dtype: float64

# %%
Clsindex.plot()

# %%
SHindex.index = pd.to_datetime(SHindex.index)
SHindex
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Indexcd</th>
#       <th>Daywk</th>
#       <th>Opnindex</th>
#       <th>Hiindex</th>
#       <th>Loindex</th>
#       <th>Clsindex</th>
#       <th>Retindex</th>
#     </tr>
#     <tr>
#       <th>Trddt</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2014-01-02</th>
#       <td>1</td>
#       <td>4</td>
#       <td>2112.126</td>
#       <td>2113.110</td>
#       <td>2101.016</td>
#       <td>2109.387</td>
#       <td>-0.003115</td>
#     </tr>
#     <tr>
# ...

# %%
SHindex.index
# Out:
# DatetimeIndex(['2014-01-02', '2014-01-03', '2014-01-06', '2014-01-07',
#                '2014-01-08', '2014-01-09', '2014-01-10', '2014-01-13',
#                '2014-01-14', '2014-01-15',
#                ...
#                '2015-03-31', '2015-04-01', '2015-04-02', '2015-04-03',
#                '2015-04-07', '2015-04-08', '2015-04-09', '2015-04-10',
#                '2015-04-13', '2015-04-14'],
#               dtype='datetime64[ns]', name='Trddt', length=311, freq=None)

# %%
SHindex.head(n =10)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Indexcd</th>
#       <th>Daywk</th>
#       <th>Opnindex</th>
#       <th>Hiindex</th>
#       <th>Loindex</th>
#       <th>Clsindex</th>
#       <th>Retindex</th>
#     </tr>
#     <tr>
#       <th>Trddt</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2014-01-02</th>
#       <td>1</td>
#       <td>4</td>
#       <td>2112.126</td>
#       <td>2113.110</td>
#       <td>2101.016</td>
#       <td>2109.387</td>
#       <td>-0.003115</td>
#     </tr>
#     <tr>
# ...

# %%
SHindex.tail(n=10)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Indexcd</th>
#       <th>Daywk</th>
#       <th>Opnindex</th>
#       <th>Hiindex</th>
#       <th>Loindex</th>
#       <th>Clsindex</th>
#       <th>Retindex</th>
#     </tr>
#     <tr>
#       <th>Trddt</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2015-03-31</th>
#       <td>1</td>
#       <td>2</td>
#       <td>3822.987</td>
#       <td>3835.567</td>
#       <td>3737.043</td>
#       <td>3747.899</td>
#       <td>-0.010212</td>
#     </tr>
#     <tr>
# ...

# %%
SHindex['2015'] #查看2015年
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Indexcd</th>
#       <th>Daywk</th>
#       <th>Opnindex</th>
#       <th>Hiindex</th>
#       <th>Loindex</th>
#       <th>Clsindex</th>
#       <th>Retindex</th>
#     </tr>
#     <tr>
#       <th>Trddt</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2015-01-05</th>
#       <td>1</td>
#       <td>1</td>
#       <td>3258.627</td>
#       <td>3369.281</td>
#       <td>3253.883</td>
#       <td>3350.519</td>
#       <td>0.035813</td>
#     </tr>
#     <tr>
# ...

# %%
SHindex['2015'].head(10)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Indexcd</th>
#       <th>Daywk</th>
#       <th>Opnindex</th>
#       <th>Hiindex</th>
#       <th>Loindex</th>
#       <th>Clsindex</th>
#       <th>Retindex</th>
#     </tr>
#     <tr>
#       <th>Trddt</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2015-01-05</th>
#       <td>1</td>
#       <td>1</td>
#       <td>3258.627</td>
#       <td>3369.281</td>
#       <td>3253.883</td>
#       <td>3350.519</td>
#       <td>0.035813</td>
#     </tr>
#     <tr>
# ...

# %%
SHindex['2015-01-16':'2015-04-09'] #按照时间截取
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Indexcd</th>
#       <th>Daywk</th>
#       <th>Opnindex</th>
#       <th>Hiindex</th>
#       <th>Loindex</th>
#       <th>Clsindex</th>
#       <th>Retindex</th>
#     </tr>
#     <tr>
#       <th>Trddt</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2015-01-16</th>
#       <td>1</td>
#       <td>5</td>
#       <td>3343.603</td>
#       <td>3400.318</td>
#       <td>3340.490</td>
#       <td>3376.495</td>
#       <td>0.012001</td>
#     </tr>
#     <tr>
# ...

# %%
Clsindex.hist()

# %%
Clsindex.max()
# Out:
# 4135.565

# %%
Clsindex.mean()
# Out:
# 2490.0011607717042

# %%
Clsindex.median()
# Out:
# 2224.654

# %%
Clsindex.std()
# Out:
# 563.7009796636235
