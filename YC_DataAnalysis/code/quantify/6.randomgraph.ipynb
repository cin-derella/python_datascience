# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
#from scipy import stats
import matplotlib
matplotlib.rcParams['font.sans-serif'] = ['SimHei']
matplotlib.rcParams['font.family'] = 'sans-serif'
matplotlib.rcParams['axes.unicode_minus'] = False

# %%
path = r'../YCdata/TRD_Index.txt'
data = pd.read_table(path,sep = '\t')
data
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Indexcd</th>
#       <th>Trddt</th>
#       <th>Daywk</th>
#       <th>Opnindex</th>
#       <th>Hiindex</th>
#       <th>Loindex</th>
#       <th>Clsindex</th>
#       <th>Retindex</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>2009-01-05</td>
#       <td>1</td>
#       <td>1849.020</td>
#       <td>1880.716</td>
#       <td>1844.094</td>
#       <td>1880.716</td>
#       <td>0.032904</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>2009-01-06</td>
#       <td>2</td>
#       <td>1878.827</td>
#       <td>1938.690</td>
# ...

# %%
SHIndex = data[data.Indexcd ==1]
SHIndex
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Indexcd</th>
#       <th>Trddt</th>
#       <th>Daywk</th>
#       <th>Opnindex</th>
#       <th>Hiindex</th>
#       <th>Loindex</th>
#       <th>Clsindex</th>
#       <th>Retindex</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>2009-01-05</td>
#       <td>1</td>
#       <td>1849.020</td>
#       <td>1880.716</td>
#       <td>1844.094</td>
#       <td>1880.716</td>
#       <td>0.032904</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>2009-01-06</td>
#       <td>2</td>
#       <td>1878.827</td>
#       <td>1938.690</td>
# ...

# %%
SZIndex = data[data.Indexcd ==399106]
SZIndex
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Indexcd</th>
#       <th>Trddt</th>
#       <th>Daywk</th>
#       <th>Opnindex</th>
#       <th>Hiindex</th>
#       <th>Loindex</th>
#       <th>Clsindex</th>
#       <th>Retindex</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>13012</th>
#       <td>399106</td>
#       <td>2009-01-05</td>
#       <td>1</td>
#       <td>560.097</td>
#       <td>571.134</td>
#       <td>557.687</td>
#       <td>571.134</td>
#       <td>0.032230</td>
#     </tr>
#     <tr>
#       <th>13013</th>
#       <td>399106</td>
#       <td>2009-01-06</td>
#       <td>2</td>
#       <td>569.278</td>
# ...

# %%
plt.scatter(SHIndex.Retindex,SZIndex.Retindex)
plt.xlabel('上海指数')
plt.ylabel('深圳指数')
plt.title('散点图')
plt.legend()
# Out:
# No handles with labels found to put in legend.

# %%
SZIndex.index = SHIndex.index  #交换索引
SZIndex.Retindex.corr(SHIndex.Retindex) #计算平均斜率
# Out:
# 0.9082776348014547
